# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pre_processing as pp
import analysis as anl
import pca

category = 'books'

hNeg = True #if true, add negative bigrams for negative reviews
noun = True #if true, add nouns

X, Y, vocabulary = pp.bow(category, hNeg, noun)

print("Vocabulário possui " + str(len(vocabulary)) + " palavras!")
# Out:
# Vocabulário possui 15269 palavras!

# %%
def normalizar(X):

    m, n = X.shape # m = qtde de objetos e n = qtde de atributos por objeto
    
    # Inicializa as variaves de saída
    X_norm = np.zeros( (m,n) ) #inicializa X_norm (base normalizada)
    #X_norm = lil_matrix((m, n))
    mu = 0 # inicializa a média
    sigma = 1 # inicializa o desvio padrão
      
    mu = np.mean(X, axis=0)
    sigma = np.std(X, axis=0, ddof=1)
    
    for i in range(m):
        for j in range(n):
            X_norm[i][j] = (X[i][j] - mu[j])/(sigma[j])
        
    return X_norm

# %% [markdown]
# Separa os dados em treinamento e teste:

# %%
# semente usada na randomizacao dos dados.
randomSeed = 10 

# gera os indices aleatorios que irao definir a ordem dos dados
idx_perm = np.random.RandomState(randomSeed).permutation(range(len(Y)))

# ordena os dados de acordo com os indices gerados aleatoriamente
X2, Y2 = X[idx_perm, :], Y[idx_perm]

#X2, Y2 = X[idx_perm, :], Y[idx_perm]

pTrain = 0.8

train_index, test_index = anl.stratified_holdOut(Y, pTrain)

Xtrain, Xval = X2[train_index, :], X2[test_index, :]
Ytrain, Yval = Y2[train_index], Y2[test_index]

# %% [markdown]
# Seleciona features com chi-quadrado (a partir dos dados de treinamento):

# %%
Xtrain, new_vocabulary, index = pp.chi2(Xtrain, Ytrain, vocabulary)
Xval = Xval[:, index]

Xtrain = Xtrain.toarray()
Xval = Xval.toarray()

# %%
print("Número de features antes do chi-quadrado: " + str(len(vocabulary)))
print("----------------------------------------")
print("Número de features após chi-quadrado: " + str(len(new_vocabulary)))
print(new_vocabulary)
# Out:
# Número de features antes do chi-quadrado: 15269
# ----------------------------------------
# Número de features após chi-quadrado: 1332
# ['child', 'nichola', 'watson', 'failur', 'enhanc', 'michel', 'weak', 'complaint', ('not', 'understand'), 'dislik', 'plod', 'batter', 'slow', 'potato', 'galbraith', 'extremist', ('never', 'realli'), 'appreci', 'garbag', 'fighter', 'dilling', 'yawn', ('not', 'believ'), 'mick', ('not', 'particularli'), 'hill', ('not', 'seem'), 'fleet', 'leo', 'literatur', 'alphabet', 'democraci', 'finish', 'dian', 'kit', 'lightman', 'lowest', 'not', 'miller', 'citat', ('not', 'buy'), 'appeal', 'hurri', 'readerwar', 'persian', 'thought', 'claim', 'food', 'primer', 'celia', 'key', 'pynchon', 'bother', ('not', 'cup'), 'fish', 'miss', 'prefer', 'qutb', 'underpin', 'determin', 'innov', 'holocaust', 'write', 'shapiro', 'brunson', 'resourc', 'slant', 'minim', 'ego', 'bubbl', 'savannah', 'thorbi', 'island', 'gpu', 'univers', 'process', 'coverag', 'believ', 'ireland', 'hunter', 'mug', 'gener', ('not', 'realli'), 'mother', 'smart', 'crush', 'someon', 'magnific', 'hate', 'care', 'histor', 'keegan', 'never', 'kind', 'pirsig', 'firm', 'gym', 'explain', 'http', 'mandelbrot', 'legendari', 'hiassin', 'stun', 'superman', 'futur', 'pursuit', 'joke', 'pollack', 'compani', 'interest', ('not', 'realiz'), 'inconsist', 'pagan', 'much', 'everglad', 'alledg', 'instead', 'lyddi', 'wrong', 'clown', 'girlfriend', 'sociolog', 'shorti', ('not', 'rememb'), 'hors', 'lyric', 'employe', 'terrif', 'argument', 'ramanujun', 'chocol', 'quinn', 'appli', 'poker', 'knight', 'julia', 'overr', 'pp', 'support', ('not', 'true'), 'anderson', 'circuit', 'turkish', 'mous', ('never', 'seem'), 'baldacci', 'unbalanc', 'juda', 'heartland', 'end', 'rambl', 'third', 'barr', 'anni', 'jacket', 'worker', 'abort', 'ld', 'whole', 'attent', 'complementari', 'unsympathet', 'convolut', ('not', 'time'), 'metabol', 'autism', 'novel', 'tale', 'syndrom', 'coal', 'nadja', 'racist', 'devoid', 'white', 'distast', 'repetit', 'twain', 'toland', 'shay', 'botox', 'vbscript', 'hell', 'spring', 'subsequ', ('not', 'worth'), 'undo', 'rather', 'honestli', 'convinc', 'least', ('not', 'enjoy'), 'satan', 'sokal', 'feet', 'rii', 'addit', ('not', 'everyon'), 'plotlin', 'mainstream', 'torpedo', ('not', 'think'), 'black', 'star', 'disproven', 'poor', 'struggl', 'kuh', 'heroic', 'commerci', 'rebellion', 'split', 'meet', 'dna', 'tower', 'get', 'attend', 'russia', 'kramer', ('not', 'bother'), 'alkalin', 'remark', 'barber', 'blustein', 'alba', ('not', 'recommend'), 'hersey', ('not', 'alreadi'), 'script', 'herb', 'string', 'marxism', 'cacao', 'unsupport', 'influenc', 'dalla', 'laughabl', 'illustr', 'negoti', 'cornwel', 'burk', ('not', 'find'), 'crawl', 'chang', 'glossi', ('not', 'found'), 'america', 'draft', 'soy', 'lai', 'open', 'vengeanc', 'cassandra', 'dewolf', 'recommend', ('not', 'also'), 'equal', ('not', 'work'), 'drastic', 'franziska', 'rear', 'valley', 'h', 'vern', ('not', 'surpris'), 'alcott', 'brook', 'darbi', 'gfcf', 'wilder', 'mickey', 'annoy', 'roark', 'maclean', 'topic', 'news', 'truli', 'cow', 'experi', 'auwiedersehen', 'exampl', 'pari', 'vicari', 'tempt', 'everyth', ('not', 'case'), 'lack', 'c', 'gift', 'hendrix', 'navi', ('not', 'help'), 'coulter', 'styron', 'sex', 'baslim', 'scatter', 'roberto', 'kemp', 'sting', 'straight', ('not', 'come'), 'sorri', 'bad', 'jess', 'carol', 'immun', 'skinni', 'carl', 'disgust', 'gunther', 'expand', 'php', 'alley', ('not', 'fan'), 'delong', 'instructor', 'goodby', 'mage', 'irrit', 'cindi', 'danni', 'scarpetta', 'narbi', 'suppos', 'film', 'antebellum', 'guard', 'explicit', 'breton', 'creme', 'multitud', 'light', ('not', 'give'), 'rose', ('not', 'get'), 'tabloid', 'vietnames', 'dull', 'trip', 'evil', 'difficulti', ('not', 'abl'), 'diabet', 'unoffici', 'observ', 'decent', 'cell', 'consult', 'ridicul', 'deepak', 'celt', 'shorten', 'asid', 'slam', 'wave', 'daisi', 'june', ('not', 'quit'), 'cope', 'famili', 'manag', 'gregori', 'stilt', 'baker', 'wwii', 'plot', 'exceedingli', 'filth', 'eccentr', 'stop', 'hanniti', 'jihad', 'dubner', 'page', 'sad', 'polem', 'andrew', 'anecdot', 'risk', 'disapp ...

# %%
def distancia(x, X):
               
    m = X.shape[0] 
    D = np.zeros(m) 

    i = 0
    for amostra in X:
        D[i] = np.linalg.norm(amostra - x)
        i += 1
                    
    return D

# %%
def knn(x, X, Y, K):
        
    y = 0 
    
    ind_viz = np.ones(K, dtype=int)
    
    D = distancia(x, X)
    
    votos = np.zeros(len(set(Y)))

    ind_viz = np.argsort(D)[:K]
    
    for indice in ind_viz:
        votos[Y[indice]] += 1 
    y = np.argmax(votos)
        
    return y

# %%
def predicao(K, Xtrain, Ytrain, Xval, Yval):
    
    Ypred = []

    for i in range(Xval.shape[0]):
        y = knn(Xval[i], Xtrain, Ytrain, K)
        Ypred.append(y)
        
    acuracia = np.sum(Ypred==Yval)/len(Yval)
    
    return Ypred, acuracia

# %%
def curva_aprendizado(X, Y, Xval, Yval):
   
    """
    Funcao usada gerar a curva de aprendizado.
  
    Parametros
    ----------
  
    X : matriz com os dados de treinamento
  
    Y : vetor com as classes dos dados de treinamento
  
    Xval : matriz com os dados de validação
  
    Yval : vetor com as classes dos dados de validação
  
    """
    
    k = 5

    # inicializa as listas que guardarao a performance no treinamento e na validacao
    perf_train = []
    perf_val = []

    classes = np.unique(Y)
    
    for i in range(10, len(Y)):
        
        Ypred, acuracia = predicao(k, X[:i], Y[:i], X[:i], Y[:i])
        perf_train.append(acuracia)

        Ypred, acuracia = predicao(k, X[:i], Y[:i], Xval, Yval)
        perf_val.append(acuracia)


    ##################################################################################
       
    # Define o tamanho da figura 
    plt.figure(figsize=(20,12))

    # Plota os dados
    plt.plot(perf_train, color='blue', linestyle='-', linewidth=1.5, label='Treino') 
    plt.plot(perf_val, color='red', linestyle='-', linewidth=1.5, label='Validação')

    # Define os nomes do eixo x e do eixo y
    plt.xlabel(r'# Qtd. de dados de treinamento',fontsize='x-large') 
    plt.ylabel(r'Acuracia',fontsize='x-large') 

    # Define o título do gráfico
    plt.title(r'Curva de aprendizado', fontsize='x-large')

    # Acrescenta um grid no gráfico
    plt.grid(axis='both')

    # Plota a legenda
    plt.legend()
    
    plt.show()

# %%
#curva_aprendizado(Xtrain, Ytrain, Xval, Yval)

# %%
#K-folds

import k_folds as kf

#Pega todos os tipos de classes 
classes = classes = np.unique(Y)

# semente usada na randomizacao dos dados.
randomSeed = 10 

# gera os indices aleatorios que irao definir a ordem dos dados
idx_perm = np.random.RandomState(randomSeed).permutation(range(len(Y)))

# ordena os dados de acordo com os indices gerados aleatoriamente
X3, Y3 = X[idx_perm, :], Y[idx_perm]

# separa os dados em k folds
nFolds = 5
folds = kf.stratified_kfolds(Y3, nFolds, classes)
K = [1, 3, 5,7,9,11]
for k in K :
    kfolds = 1
    resultados=[] # cria uma lista vazia para guardar os resultados obtidos em cada fold
    for train_index, test_index in folds:

        print('\n-----------\n%d-fold: \n-----------\n' % (kfolds) )

        # se train_index ou test_index forem vazios, interrompe o laco de repeticao
        if len(train_index)==0 or len(test_index)==0: 
            print('\tErro: o vetor com os indices de treinamento ou o vetor com os indices de teste esta vazio')      
            break

        totalFold = len(train_index)+len(test_index)

        Xtrain, Xtest = X3[train_index, :], X3[test_index, :];
        Ytrain, Ytest = Y3[train_index], Y3[test_index];

        Xtrain, new_vocabulary, index = pp.chi2(Xtrain, Ytrain, vocabulary)
        Xtest = Xtest[:,index]

        Xtrain = Xtrain.toarray()
        Xtest = Xtest.toarray()

        i = 0
        #resultados=[[] for i in range(5)]
       
           
        print("K = " + str(k))
        Ypred, acuracia = predicao(k, Xtrain, Ytrain, Xtest, Ytest)
        print(acuracia)
        auxResults = anl.relatorioDesempenho(Ytest, Ypred, classes, imprimeRelatorio=True)
        # adiciona os resultados do fold atual na lista de resultados
        resultados.append( auxResults )
        kfolds+=1
        i = 0
    kf.mediaFolds( resultados, classes )
# Out:
# -----------
# 1-fold:
# -----------
#
# K = 1
# 0.7
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.600       0.750      0.667      0
# 	0.800       0.667      0.727      1
# 	------------------------------------------------
# 	0.700       0.708      0.704      Média macro
# 	0.700       0.700      0.700      Média micro
#
# 	Acuracia: 0.700
#
# -----------
# 2-fold:
# -----------
#
# K = 1
# 0.6725
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.675       0.672      0.673      0
# 	0.670       0.673      0.672      1
# 	------------------------------------------------
# 	0.673       0.673      0.673      Média macro
# 	0.672       0.672      0.672      Média micro
#
# 	Acuracia: 0.672
#
# -----------
# 3-fold:
# -----------
#
# K = 1
# 0.675
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.650       0.684      0.667      0
# 	0.700       0.667      0.683      1
# 	------------------------------------------------
# 	0.675       0.675      0.675      Média macro
# 	0.675       0.675      0.675      Média micro
#
# 	Acuracia: 0.675
#
# -----------
# 4-fold:
# -----------
#
# K = 1
# 0.6625
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.605       0.684      0.642      0
# 	0.720       0.646      0.681      1
# 	------------------------------------------------
# 	0.662       0.665      0.664      Média macro
# 	0.662       0.662      0.662      Média micro
#
# 	Acuracia: 0.662
#
# -----------
# 5-fold:
# -----------
#
# K = 1
# 0.6875
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.555       0.755      0.640      0
# 	0.820       0.648      0.724      1
# 	------------------------------------------------
# 	0.688       0.702      0.695      Média macro
# 	0.688       0.688      0.688      Média micro
#
# 	Acuracia: 0.688
#
# -----------
# Media-fold:
# -----------
#
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.617       0.709      0.658      0
# 	0.742       0.660      0.697      1
# 	---------------------------------------------------------------------
# 	0.680       0.685      0.682      Média macro
# 	0.680       0.680      0.680      Média micro
#
# 	Acuracia: 0.680
#
# -----------
# 1-fold:
# -----------
#
# K = 3
# 0.6675
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.540       0.725      0.619      0
# 	0.795       0.633      0.705      1
# 	------------------------------------------------
# 	0.667       0.679      0.673      Média macro
# 	0.667       0.667      0.667      Média micro
#
# 	Acuracia: 0.667
#
# -----------
# 2-fold:
# -----------
#
# K = 3
# 0.695
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.650       0.714      0.681      0
# 	0.740       0.679      0.708      1
# 	------------------------------------------------
# 	0.695       0.697      0.696      Média macro
# 	0.695       0.695      0.695      Média micro
#
# 	Acuracia: 0.695
#
# -----------
# 3-fold:
# -----------
#
# K = 3
# 0.6925
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.615       0.728      0.667      0
# 	0.770       0.667      0.715      1
# 	------------------------------------------------
# 	0.693       0.697      0.695      Média macro
# 	0.693       0.693      0.693      Média micro
#
# 	Acuracia: 0.693
#
# -----------
# 4-fold:
# -----------
#
# K = 3
# 0.6725
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.555       0.725      0.629      0
# 	0.790       0.640      0.707      1
# 	------------------------------------------------
# 	0.673       0.683      0.678      Média macro
# 	0.672       0.672      0.672      Média micro
#
# 	Acuracia: 0.672
#
# -----------
# 5-fold:
# -----------
#
# K = 3
# 0.6975
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.575       0.762      0.655      0
# 	0.820       0.659      0.731      1
# 	------------------------------------------------
# 	0.698       0.710      0.704      Média macro
# 	0.698       0.698      0.698      Média micro
#
# 	Acuracia: 0.698
#
# -----------
# Media-fold:
# -----------
#
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.587       0.731      0.650      0
# 	0.783       0.655      0.713      1
# 	---------------------------------------------------------------------
# 	0.685       0.693      0.689      Média macro
# 	0.685       0.685      0.685      Média micro
#
# 	Acuracia: 0.685
#
# -----------
# 1-fold:
# -----------
#
# K = 5
# 0.6875
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.525       0.778      0.627      0
# 	0.850       0.642      0.731      1
# 	------------------------------------------------
# 	0.688       0.710      0.698      Média macro
# 	0.688       0.688      0.688      Média micro
#
# 	Acuracia: 0.688
#
# -----------
# 2-fold:
# -----------
#
# K = 5
# 0.7525
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.665       0.806      0.729      0
# 	0.840       0.715      0.772      1
# 	------------------------------------------------
# 	0.752       0.760      0.756      Média macro
# 	0.752       0.752      0.752      Média micro
#
# 	Acuracia: 0.752
#
# -----------
# 3-fold:
# -----------
#
# K = 5
# 0.715
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.610       0.772      0.682      0
# 	0.820       0.678      0.742      1
# 	------------------------------------------------
# 	0.715       0.725      0.720      Média macro
# 	0.715       0.715      0.715      Média micro
#
# 	Acuracia: 0.715
#
# -----------
# 4-fold:
# -----------
#
# K = 5
# 0.7025
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.550       0.791      0.649      0
# 	0.855       0.655      0.742      1
# 	------------------------------------------------
# 	0.703       0.723      0.713      Média macro
# 	0.703       0.703      0.703      Média micro
#
# 	Acuracia: 0.703
#
# -----------
# 5-fold:
# -----------
#
# K = 5
# 0.69
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.530       0.779      0.631      0
# 	0.850       0.644      0.733      1
# 	------------------------------------------------
# 	0.690       0.712      0.701      Média macro
# 	0.690       0.690      0.690      Média micro
#
# 	Acuracia: 0.690
#
# -----------
# Media-fold:
# -----------
#
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.576       0.785      0.663      0
# 	0.843       0.667      0.744      1
# 	---------------------------------------------------------------------
# 	0.710       0.726      0.718      Média macro
# 	0.710       0.710      0.710      Média micro
#
# 	Acuracia: 0.710
#
# -----------
# 1-fold:
# -----------
#
# K = 7
# 0.685
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.500       0.794      0.613      0
# 	0.870       0.635      0.734      1
# 	------------------------------------------------
# 	0.685       0.714      0.699      Média macro
# 	0.685       0.685      0.685      Média micro
#
# 	Acuracia: 0.685
#
# -----------
# 2-fold:
# -----------
#
# K = 7
# 0.76
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.665       0.821      0.735      0
# 	0.855       0.718      0.781      1
# 	------------------------------------------------
# 	0.760       0.770      0.765      Média macro
# 	0.760       0.760      0.760      Média micro
#
# 	Acuracia: 0.760
#
# -----------
# 3-fold:
# -----------
#
# K = 7
# 0.725
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.570       0.826      0.675      0
# 	0.880       0.672      0.762      1
# 	------------------------------------------------
# 	0.725       0.749      0.737      Média macro
# 	0.725       0.725      0.725      Média micro
#
# 	Acuracia: 0.725
#
# -----------
# 4-fold:
# -----------
#
# K = 7
# 0.71
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.490       0.875      0.628      0
# 	0.930       0.646      0.762      1
# 	------------------------------------------------
# 	0.710       0.760      0.734      Média macro
# 	0.710       0.710      0.710      Média micro
#
# 	Acuracia: 0.710
#
# -----------
# 5-fold:
# -----------
#
# K = 7
# 0.7175
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.545       0.832      0.659      0
# 	0.890       0.662      0.759      1
# 	------------------------------------------------
# 	0.718       0.747      0.732      Média macro
# 	0.718       0.718      0.718      Média micro
#
# 	Acuracia: 0.718
#
# -----------
# Media-fold:
# -----------
#
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.554       0.830      0.662      0
# 	0.885       0.667      0.760      1
# 	---------------------------------------------------------------------
# 	0.720       0.748      0.733      Média macro
# 	0.720       0.720      0.720      Média micro
#
# 	Acuracia: 0.720
#
# -----------
# 1-fold:
# -----------
#
# K = 9
# 0.7
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.495       0.839      0.623      0
# 	0.905       0.642      0.751      1
# 	------------------------------------------------
# 	0.700       0.740      0.720      Média macro
# 	0.700       0.700      0.700      Média micro
#
# 	Acuracia: 0.700
#
# -----------
# 2-fold:
# -----------
#
# K = 9
# 0.7525
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.630       0.834      0.718      0
# 	0.875       0.703      0.780      1
# 	------------------------------------------------
# 	0.752       0.769      0.760      Média macro
# 	0.752       0.752      0.752      Média micro
#
# 	Acuracia: 0.752
#
# -----------
# 3-fold:
# -----------
#
# K = 9
# 0.7075
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.530       0.822      0.644      0
# 	0.885       0.653      0.752      1
# 	------------------------------------------------
# 	0.708       0.737      0.722      Média macro
# 	0.708       0.708      0.708      Média micro
#
# 	Acuracia: 0.708
#
# -----------
# 4-fold:
# -----------
#
# K = 9
# 0.695
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.465       0.861      0.604      0
# 	0.925       0.634      0.752      1
# 	------------------------------------------------
# 	0.695       0.747      0.720      Média macro
# 	0.695       0.695      0.695      Média micro
#
# 	Acuracia: 0.695
#
# -----------
# 5-fold:
# -----------
#
# K = 9
# 0.7175
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.540       0.837      0.657      0
# 	0.895       0.661      0.760      1
# 	------------------------------------------------
# 	0.718       0.749      0.733      Média macro
# 	0.718       0.718      0.718      Média micro
#
# 	Acuracia: 0.718
#
# -----------
# Media-fold:
# -----------
#
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.532       0.839      0.649      0
# 	0.897       0.658      0.759      1
# 	---------------------------------------------------------------------
# 	0.715       0.749      0.731      Média macro
# 	0.714       0.714      0.714      Média micro
#
# 	Acuracia: 0.714
#
# -----------
# 1-fold:
# -----------
#
# K = 11
# 0.7
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.465       0.877      0.608      0
# 	0.935       0.636      0.757      1
# 	------------------------------------------------
# 	0.700       0.757      0.727      Média macro
# 	0.700       0.700      0.700      Média micro
#
# 	Acuracia: 0.700
#
# -----------
# 2-fold:
# -----------
#
# K = 11
# 0.735
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.585       0.836      0.688      0
# 	0.885       0.681      0.770      1
# 	------------------------------------------------
# 	0.735       0.758      0.746      Média macro
# 	0.735       0.735      0.735      Média micro
#
# 	Acuracia: 0.735
#
# -----------
# 3-fold:
# -----------
#
# K = 11
# 0.6975
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.480       0.850      0.613      0
# 	0.915       0.638      0.752      1
# 	------------------------------------------------
# 	0.698       0.744      0.720      Média macro
# 	0.698       0.698      0.698      Média micro
#
# 	Acuracia: 0.698
#
# -----------
# 4-fold:
# -----------
#
# K = 11
# 0.705
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.455       0.910      0.607      0
# 	0.955       0.637      0.764      1
# 	------------------------------------------------
# 	0.705       0.773      0.738      Média macro
# 	0.705       0.705      0.705      Média micro
#
# 	Acuracia: 0.705
#
# -----------
# 5-fold:
# -----------
#
# K = 11
# 0.715
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.505       0.871      0.639      0
# 	0.925       0.651      0.764      1
# 	------------------------------------------------
# 	0.715       0.761      0.737      Média macro
# 	0.715       0.715      0.715      Média micro
#
# 	Acuracia: 0.715
#
# -----------
# Media-fold:
# -----------
#
#
# 	Revocacao   Precisao   F-medida   Classe
# 	0.498       0.869      0.631      0
# 	0.923       0.649      0.761      1
# 	---------------------------------------------------------------------
# 	0.711       0.759      0.734      Média macro
# 	0.711       0.711      0.711      Média micro
#
# 	Acuracia: 0.711
